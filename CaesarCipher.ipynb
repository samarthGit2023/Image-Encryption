# %% [markdown]
# <a href="https://colab.research.google.com/github/samarthGit2023/Image-Encryption/blob/main/CaesarCipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycryptodome
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 42.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# The **pycryptodome** package is installed for cryptographic operations.

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# The **pillow** package is installed for image processing.

# %%
from PIL import Image
def encrypt_image(input_path, output_path):
    # Load the image
    image = Image.open(input_path)

    # Convert the image to grayscale
    image = image.convert('L')

    # Get the image size
    width, height = image.size

    # Create a new grayscale image with the same size
    encrypted_image = Image.new('L', (width, height))

    # Apply ROT13 to the pixel values
    for y in range(height):
        for x in range(width):
            # Get the grayscale value of the current pixel
            pixel = image.getpixel((x, y))

            # Apply ROT13 to the grayscale value
            encrypted_pixel = (pixel + 123) % 256

            # Set the modified grayscale value to the new image
            encrypted_image.putpixel((x, y), encrypted_pixel)

    # Save the encrypted image
    encrypted_image.save(output_path)

    print("Image encrypted and saved successfully!")

# Path to the input grayscale image
input_image_path = 'madara.jpg'

# Path to save the encrypted grayscale image
encrypted_image_path = 'encrypted_image_gray.jpg'

# Encrypt the grayscale image
encrypt_image(input_image_path, encrypted_image_path)
# Out:
# Image encrypted and saved successfully!

# %% [markdown]
# * In the above code, we take any desired image as an input and we try to encrypt it using a simple **Caesar cipher** algorithm.
# * The encrypt_image function takes input image and output image path and it converts the coloured input image to a grayscale image. After conversion we traverse every pixel of the grayscale image and apply caesar cipher algorithm for encrypting it. The grayscale value of a pixel ranges form 0 to 255, thus we take any random number as key and shift it as :
# * **Encrypted_pixel = (pixel + x) % 256**
# * The encrypted_image serves as a blank canvas where the modified grayscale values, resulting from the encryption process, will be stored. Thus we get the encryption of the input image.

# %%
# !pip install scikit-image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# The scikit-image package is a Python library for image processing that provides a collection of algorithms and tools for various image-related tasks.

# %%
import cv2
import skimage.metrics as metrics

def compare_images(original_path, encrypted_path):
    # Read the images
    original_image = cv2.imread(original_path)
    encrypted_image = cv2.imread(encrypted_path)

    # Ensure the same dimensions
    original_image = cv2.resize(original_image, (encrypted_image.shape[1], encrypted_image.shape[0]))

    # Convert images to grayscale if needed
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
    encrypted_image = cv2.cvtColor(encrypted_image, cv2.COLOR_BGR2GRAY)

    # Calculate mean squared error (MSE)
    mse = metrics.mean_squared_error(original_image, encrypted_image)

    return mse

# Example usage
original_path = '/content/madara.jpg'
encrypted_path = '/content/encrypted_image_gray.jpg'

mse = compare_images(original_path, encrypted_path)
print(f"The mean squared error (MSE) between the images is: {mse}")
# Out:
# The mean squared error (MSE) between the images is: 2514.9583960923624

# %% [markdown]
# * In the above code, we compare the original grayscale image and the encrypted image by measuring the mean squared error between both images.
# * Original Image :![madara.jpg](data:image/jpeg;base64,...)
# * Encrypted Image : ![encrypted_image_gray.jpg](data:image/jpeg;base64,...)
